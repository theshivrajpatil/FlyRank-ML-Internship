# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# #### Task Type: Scoring / Ranking
# - Lane Chosen: Refresh / Content Opportunity Scoring
# - ML Task Type: Scoring / Ranking
# - Goal: Rank content pages based on their refresh priority.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# #### Target or Proxy
# - Predict which pages should be refreshed first.
# - Use historical performance signals as a proxy target.
# - Pages with declining performance are considered higher refresh opportunities.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# #### Success Metric
#
# - Precision@K
# - Recall@K
# - Ranking quality of top recommended pages.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# #### Action Supported
#
# - Content teams refresh high-priority pages first.
# - Resources are focused on pages with the highest potential impact.
# - Reduce manual effort in finding pages to update.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# #### Why ML Beats Fixed Rules
#
# - Fixed rules use only one or two signals.
# - ML combines multiple signals simultaneously.
# - ML can detect complex patterns that fixed rules miss.
# - ML adapts better to different page behaviors.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
