# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
print("""
Unit of analysis:
Row represents one content page (content_id) and its SEO, content quality, and performance metrics.

Time window:
This dataset is a single anonymized snapshot and does not contain daily or monthly timestamps.
The analysis is performed on the complete snapshot.
""")
# Out:
# Unit of analysis:
# Row represents one content page (content_id) and its SEO, content quality, and performance metrics.
#
# Time window:
# This dataset is a single anonymized snapshot and does not contain daily or monthly timestamps.
# The analysis is performed on the complete snapshot.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
print("""
Feature Fields:
- search_volume
- competition
- word_count
- ctr
- avg_position

Label:
- trend_direction

Context:
- content_id
- client_id
- content_type
- provider_used
- model_used

Excluded:
- trend_pct (derived from the trend label)
- content_id
- client_id

Reason:
Identifiers do not help prediction, and trend_pct directly reflects the outcome,
which can introduce target leakage.
""")
# Out:
# Feature Fields:
# - search_volume
# - competition
# - word_count
# - ctr
# - avg_position
#
# Label:
# - trend_direction
#
# Context:
# - content_id
# - client_id
# - content_type
# - provider_used
# - model_used
#
# Excluded:
# - trend_pct (derived from the trend label)
# - content_id
# - client_id
#
# Reason:
# Identifiers do not help prediction, and trend_pct directly reflects the outcome,
# which can introduce target leakage.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd
df = pd.read_csv("/Users/theshivrajpatil/FlyRank-ML-Internship/data/raw/content_refresh_anonymized.csv")

# %%
# grain
print("Total Rows :", len(df))
print("Unique Content IDs :", df["content_id"].nunique())
# Out:
# Total Rows : 30000
# Unique Content IDs : 30000

# %%
# count rows and columns
print("Row Count :", len(df))
print("Column Count :", len(df.columns))

print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Row Count : 30000
# Column Count : 44
#
# Column Names:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
# missing values and availability

availability_df = pd.DataFrame({
    "Column": df.columns,
    "Available Values": df.notnull().sum().values,
    "Missing Values": df.isnull().sum().values,
    "Availability (%)": ((df.notnull().sum()/len(df))*100).round(2).values
})

availability_df
# Out:
#                     Column  Available Values  Missing Values  Availability (%)
# 0               content_id             30000               0            100.00
# 1                client_id             30000               0            100.00
# 2            search_volume             27532            2468             91.77
# 3              competition             27532            2468             91.77
# 4        competition_level             27390            2610             91.30
# 5                      cpc             27532            2468             91.77
# 6             content_type             30000               0            100.00
# 7              main_intent             27626            2374             92.09
# 8               word_count             22301            7699             74.34
# 9               char_count             22301            7699             74.34
# 10           provider_used              8562           21438             28.54
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
print("""Limitation:
The Content Refresh dataset is an anonymized snapshot, so it does not include any time-based information.
This means I cannot analyze trends over time or measure how content performance changes.
Since the data is anonymized, I also cannot interpret the actual content, which limits the scope of the analysis.""")
# Out:
# Limitation:
# The Content Refresh dataset is an anonymized snapshot, so it does not include any time-based information.
# This means I cannot analyze trends over time or measure how content performance changes.
# Since the data is anonymized, I also cannot interpret the actual content, which limits the scope of the analysis.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it.
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all).
# - [x] No client names, URLs, or private queries anywhere.
# - [x] My claims use careful words: observed, measured, directional, and decision-support.
# - [x] Committed to my repo under `work/notebooks/` — then submitted my repo URL on the card.
